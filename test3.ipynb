# %%
# selenium beaurifulsoup Requests
#크롤링라이브러리

#! pip install selenium

# %%
import selenium

from selenium import webdriver

# browser = webdriver.Chrome()
url = "https://weather.naver.com/"
# browser.get(url)
# browser.page_source
# Out:
# '<html lang="ko" data-platform="pc" data-useragent="mozilla/5.0 (macintosh; intel mac os x 10_15_7) applewebkit/537.36 (khtml, like gecko) chrome/151.0.0.0 safari/537.36" class=""><head>\n        <meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width,initial-scale=1.0,user-scalable=no,maximum-scale=1">\n<meta name="format-detection" content="telephone=no">\n<meta property="og:title" content="네이버 날씨 홈">\n<meta property="og:url" content="https://weather.naver.com/today">\n<meta property="og:image" content="https://ssl.pstatic.net/static/weather/image/img_og_weather_400x210.png">\n<meta property="og:image:width" content="800">\n<meta property="og:image:height" content="420">\n<meta property="og:description" content="전국 모든 읍・면・동의 현재 날씨와 시간별 예보, 주간 예보를 제공합니다.">\n\n<link rel="canonical" href="https://weather.naver.com/today">\n<link rel="shortcut icon" href="https://ssl.pstatic.net/static/weather/images/Favicon_32x32.svg" type="image/x-icon">\n<link rel="preload" href="https://ssl.pstatic.net/static/weather/font/NotoSans-Regular.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/NotoSans-Light.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/NotoSans-Medium.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/NotoSans-Bold.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/Roboto-Light.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/Roboto-Regular.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/Roboto-Medium.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/Roboto-Bold.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/NanumSquareNeoTTF-cBd.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://ssl.pstatic.net/static/weather/font/NanumSquareNeoTTF-dEb.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static/weather/images/iOS_iPhone@2x_120X120.png">\n        <link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static/weather/images/iOS_iPad_152X152.png">\n        <link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static/weather/images/iOS_iPadPro@2x_167X167.png">\n        <link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static/weather/images/iOS_iPhone@3x_180X180.png">\n    <title>네이버 날씨 홈</title>\n<meta name="description" content="전국 모든 읍・면・동의 현재 날씨와 시간별 예보, 주간 예보를 제공합니다.">\n\n<!-- Naver Tag Manager -->\n        <script async="" src="https://ntm.pstatic.net/ex/nlog.js"></script><script async="" src="https://ntm.pstatic.net/scripts/ntm_f6905c3401d4.js"></script><script type="text/javascript">\n            !function(t,n){n=n||"ntm";window["ntm_"+t]=n,window[n]=window[n]||[],window[n].push({"ntm.start":+new Date});t=document.getElementsByTagName("script")[0],n=document.createElement("script");n.async=!0,n.src="https://ntm.pstatic.net/scripts/ntm_f6905c3401d4.js",t.parentNode.insertBefore(n,t)}("f6905c3401d4","ntm");\n        </script>\n        <!-- End Naver Tag Manager -->\n    <script>\n\tvar devCssBranch = "260723";\n</script>\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/staticv2.weather/responsive/css/lib/billboard/billboard-3.7.1.min.c ...

# %%
from bs4 import BeautifulSoup
import requests

response = requests.get(url)
# browser = requests.get(url)
# soup = BeautifulSoup(browser.page_source, "html.parser")
# soup.select
soup = BeautifulSoup(response.text, "html.parser")
soup.find_all('li', class_="tommrow")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 from bs4 import BeautifulSoup
# ----> 2 soup = BeautifulSoup(browser.page_source, "html.parser")
#       3 # soup.select
#       4 soup.find_all('li', class_="tommrow")
#
# File ~/PythonProject/python-study/.venv/lib/python3.13/site-packages/bs4/__init__.py:445, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     443     markup = cast(io.IOBase, markup).read()
#     444 elif not isinstance(markup, (bytes, str)) and not hasattr(markup, "__len__"):
# --> 445     raise TypeError(
#     446         f"Incoming markup is of an invalid type: {markup!r}. Markup must be a string, a bytestring, or an open filehandle."
#     447     )
#     448 elif isinstance(markup, Sized) and len(markup) <= 256 and (
#     449     (isinstance(markup, bytes) and b"<" not in markup and b"\n" not in markup)
#     450     or (isinstance(markup, str) and "<" not in markup and "\n" not in markup)
#    (...)    454     # Beautiful Soup will still parse the input as markup,
#     455     # since that is sometimes the intended behavior.
#     456     if not self._markup_is_url(markup):
#
# TypeError: Incoming markup is of an invalid type: None. Markup must be a string, a bytestring, or an open filehandle.
