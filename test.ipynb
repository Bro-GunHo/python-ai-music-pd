# %%
print("hellow world")

rr = '안녕'
print(rr)
# Out:
# hellow world
# 안녕

# %%
price = 3000
# price = 6000
print(price)
# Out:
# 3000

# %%
a = 9
b = 5
print(a+b)
print(a -b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 14
# 4
# 45
# 1.8
# 1
# 4

# %%
c1 = "산"
c2 = "토끼"
print(c1+c2)
# Out:
# 산토끼

# %%
print('-' * 60)
# Out:
# ------------------------------------------------------------

# %%
list_empty = ['장남수', '홍길동', '장주원', '이순신']
print(list_empty)
# Out:
# ['장남수', '홍길동', '장주원', '이순신']

# %%
print(list_empty[1])
print(list_empty[-1])
# Out:
# 홍길동
# 이순신

# %%
#리스트 [시작인덱스:종료인덱스]
print(list_empty[0:3])
print(list_empty[:-1])
print(list_empty[-4:3])
print(list_empty[-3:])
print(len(list_empty))
# Out:
# ['장남수', '홍길동', '장주원']
# ['장남수', '홍길동', '장주원']
# ['장남수', '홍길동', '장주원']
# ['홍길동', '장주원', '이순신']
# 4

# %%
print(1)
# Out:
# 1

# %%
# for 변수명 in 그룹명:
#   실행코드

customer_list = ['장남수', '홍길동', '장주원', '이순신']

for customer in customer_list:
    print(customer)
    print(1)
print(2)
# Out:
# 장남수
# 1
# 홍길동
# 1
# 장주원
# 1
# 이순신
# 1
# 2
